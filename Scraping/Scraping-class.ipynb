# %% [markdown]
# # Request (tipo curl)
#
# * Request es la biblioteca en python para hacer peticiones HTTP.
# * Puedo hacer programáticamente una petición con:
#     * Headers.
#
#     * Body.
#
#     * Tipo de petición.
#
#     * Manejo de sesión (cookies).
#
# * Al crear una petición, se genera un objeto con los siguientes atributos:
#
#     * status code
#         Código de respuesta de la petición. Existe un universo finito de códigos que pueden revisar en wikipedia (https://es.wikipedia.org/wiki/Anexo:C%C3%B3digos_de_estado_HTTP).
#
#     * encoding
#         Codificación original de la página web.
#         ISO-8859-1 es el famosísimo Windows.
#         UTF-8 existe en linux.
#
#     * headers
#         Encabezados de la petición web. Así como nosotros agregamos encabezados al realizar peticiones, el servidor hace lo mismo.
#
#     * text
#         El HTML/JSON/lo que se regresa en el body del paquete.

# %%
import requests
r  = requests.get("http://www.banxico.org.mx/SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCuadro&idCuadro=CF300&locale=es")

# %%
r.status_code
# Out:
# 200

# %%
r.encoding
# Out:
# 'ISO-8859-1'

# %% [markdown]
# ### ¿Que información nos regresa los headers del servidor?

# %%
r.headers
# Out:
# {'Set-Cookie': 'JSESSIONID=db982a8dfb7931ccc9acf9a01787; Path=/SieInternet; HttpOnly, test1=659441322.36895.0000; path=/, TS014a759c=0189f484afb4a8432c2208a0771d5051c81de1ec6dd7f75bbc3967bc4930c86d6f1c39809dd916cc9d771d79be8c139ea483b00146a4637d0d9376a623635bc6793dce5be8; Path=/, TS01b274c3=0189f484afe6d87d49039738364159bf345ffccab0d7f75bbc3967bc4930c86d6f1c39809d4d4bb972c6f8046a25e2f3983454bd8bfac47c49ac191c58535ee740f2bf1085; path=/SieInternet, ORF_wwwBanx=2505459370.20480.0000; path=/', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=ISO-8859-1', 'X-Powered-By': 'Servlet/3.1 JSP/2.3 (GlassFish Server Open Source Edition  4.1  Java/Oracle Corporation/1.8)', 'Date': 'Wed, 06 Dec 2017 21:27:00 GMT'}

# %%
r.text
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html>\r\n\r\n\r\n<head>\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n    <meta name="robots" content="index, nofollow">\r\n\t<meta name="viewport" content="initial-scale=1,user-scalable=no,maximum-scale=1,width=device-width"> \r\n\r\n\r\n    <title>Consulta de Estructura de Informaci&oacute;n</title>\r\n\r\n    <script language="Javascript" src="/SieInternet/js/ConsultarDirectorio/ConsultarDirectorioUtil.js"></script>\r\n    <script language="Javascript" src="/SieInternet/js/ConsultarDirectorio/ConsultarDirectorioControles.js"></script>\r\n    <script language="Javascript" src="/SieInternet/js/ConsultarDirectorio/ConsultarDirectorioValida.js"></script>\r\n    <script language="Javascript" src="/SieInternet/js/ConsultarDirectorio/ConsultarDirectorioCarritoSeries.js"></script>\r\n    <script language="Javascript" src="/SieInternet/js/jquery-1.9.1.min.js"></script>\r\n    <script src="/SieInternet/js/jquery.colorbox.js"></script>\r\n    <script type="text/javascript" src="/SieInternet/js/treetable.js"></script>\r\n    <script language="Javascript" src="/SieInternet/js/ConsultarDirectorio/ConsultarDirectorioOpcionesConsulta.js"></script>\r\n    <script language="Javascript" src="/SieInternet/js/ConsultarDirectorio/scrollTabla.js"></script>\r\n\t<script language="Javascript" src="/SieInternet/js/bootstrap.min.js"></script>\r\n\t<script language="Javascript" src="/SieInternet/js/bootstrap-datepicker.min.js"></script>\r\n\t<script language="Javascript" src="/SieInternet/js/bootstrap-datepicker.es.min.js"></script>\r\n\t\t\r\n\t<link media="screen" rel="stylesheet" href="/SieInternet/css/bootstrap.min.css" type="text/css">\r\n\t<link media="screen" rel="stylesheet" href="/SieInternet/css/bootstrap-datepicker3.min.css">\r\n    \r\n    <link media="screen" href="/SieInternet/css/ConsultarDirectorioEstilos.css" rel="StyleSheet" type="text/css">\r\n    <link media="print" href="/SieInternet/css/ConsultarDirectorioEstilos_print.css" rel="StyleSheet" type="text/css">\r\n    \r\n    <link media="screen" href="/SieInternet/css/colorbox.css" rel="stylesheet" />\r\n    <link media="screen" rel="StyleSheet" href="/SieInternet/css/ConsultarDirectorioOpcionesConsulta.css" type="text/css">\r\n    <link media="screen" rel="StyleSheet" href="/SieInternet/css/scrollTabla.css" type="text/css">\r\n\t\r\n\r\n\r\n    <style>\r\n        \r\n        .imgH {\r\n            width: 15px;\r\n            height: 15px;\r\n            margin-left: 2px;\r\n            border: none;\r\n            vertical-align: middle;\r\n        }\r\n\t\tinput[type=checkbox], input[type=radio] {\r\n\t\t\tmargin:0px;\r\n\t\t}\r\n\t\tlabel{\r\n\t\t\tdisplay:inline;\r\n\t\t\t}\r\n \r\n    </style>\r\n\r\n    \r\n        \r\n        \r\n        \r\n        \r\n    \r\n    \r\n\r\n    <script>\r\n        var expand = new Image();\r\n        expand.src = "/SieInternet/img/toggle-expand-dark.png";\r\n        var collapse = new Image();\r\n        collapse.src = "/SieInternet/img/toggle-collapse-dark.png";\r\n\r\n        function desplegarArbol(){\r\n            var liga=$("#toggleRamasEstadoInicialTexto").text();\r\n            if ($("#toggleRamasEstadoInicialTexto").text().trim()=="Ver todo") {\r\n                /* abre todas las ramas */\r\n                treetable_expandAll(\'treeTable\');\r\n\r\n                /* abre todas las flechas */\r\n                $("img[id^=\'img_nodo\']").attr("src",collapse.src);\r\n\r\n                /* Cambia el texto y la flecha del control que abre y cierra todas las ramas */\r\n                $("#toggleRamasEstadoInicialTexto").text("Contraer");\r\n                $("#toggleRamasEstadoInicialImagen").attr("src","/SieInternet/img/toggle-collapse-dark.png");\r\n            } else {\r\n                /* reestablece las ramas a su visibilidad inicial */\r\n     ...

# %% [markdown]
# # BeautifulSoup (BS4)
#
# * Parser mágico en Python.
#
# * Transforma una cadena de texto con HTML a un objeto en el cual podemos buscar, iterar, modificar.
#
# * Pueden revisar la documentación en https://www.crummy.com/software/BeautifulSoup/bs4/doc/.
#
# * Requests + BS4 son parte del navaja suiza.

# %%
from bs4 import BeautifulSoup


r  = requests.get("http://www.banxico.org.mx/SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCuadro&idCuadro=CF300&locale=es")

data = r.text

soup = BeautifulSoup(data)

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# C:\Users\FORANEA110\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file C:\Users\FORANEA110\AppData\Local\Continuum\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# http://www.banxico.org.mx
# #
# #
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&idCuadro=CF300&accion=consultarCuadro&locale=en
# /SieInternet/
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarDirectorioCuadros&locale=es
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCarritoDeSeries&idCuadro=CF300&locale=es
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCarritoDeSeries&idCuadro=CF300&locale=es
# #
# /SieInternet/generaSerieGrafica.do?s=SF45422,CF300,2&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45438,CF300,3&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45439,CF300,4&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45470,CF300,5&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45423,CF300,6&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45440,CF300,7&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45441,CF300,8&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45471,CF300,9&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45424,CF300,10&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45442,CF300,11&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45443,CF300,12&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45472,CF300,13&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45425,CF300,14&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45444,CF300,15&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45445,CF300,16&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45473,CF300,17&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45426,CF300,19&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45446,CF300,20&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45447,CF300,21&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45474,CF300,22&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59767,CF300,24&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59773,CF300,25&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59774,CF300,26&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59770,CF300,27&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59768,CF300,28&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59775,CF300,29&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59776,CF300,30&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59771,CF300,31&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59769,CF300,32&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59777,CF300,33&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59778,CF300,34&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59772,CF300,35&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45427,CF300,37&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45448,CF300,38&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45449,CF300,39&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45475,CF300,40&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45428,CF300,41&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45450,CF300,42&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45451,CF300,43&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45476,CF300,44&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45429,CF300,45&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45452,CF300,46&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45453,CF300,47&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45477,CF300,48&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45430,CF300,49&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45454,CF300,50&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45455,CF300,51&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45478,CF300,52&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45431,CF300,53&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45456,CF300,54&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45457,CF300,55&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45479,CF300,56&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60720,CF300,57&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60721,CF300,58&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60722,CF300,59&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60723,CF300,60&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61784,CF300,62&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61785,CF300,63&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61786,CF300,64&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61787,CF300,65&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45432,CF300,66&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45458,CF300,67&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45459,CF300,68&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45480,CF300,69&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50761,CF300,70&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50765,CF300,71&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50766,CF300,72&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50763,CF300,73&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50762,CF300,74&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50767,CF300,75&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50768,CF300,76&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50764,CF300,77&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64846,CF300,79&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64847,CF300,80&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64848,CF300,81&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64849,CF300,82&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108413,CF300,83&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108414,CF300,84&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108415,CF300,85&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108416,CF300,86&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45433,CF300,87&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45460,CF300,88&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45461,CF300,89&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45481,CF300,90&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66800,CF300,92&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66801,CF300,93&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66802,CF300,94&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66803,CF300,95&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161926,CF300,96&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161928,CF300,97&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161930,CF300,98&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161932,CF300,99&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45435,CF300,100&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45464,CF300,101&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45465,CF300,102&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45483,CF300,103&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66804,CF300,105&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66805,CF300,106&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66806,CF300,107&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66807,CF300,108&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161927,CF300,109&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161929,CF300,110&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161931,CF300,111&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161933,CF300,112&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45434,CF300,113&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45462,CF300,114&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45463,CF300,115&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45482,CF300,116&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165596,CF300,118&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165598,CF300,119&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165600,CF300,120&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165602,CF300,121&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165597,CF300,123&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165599,CF300,124&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165601,CF300,125&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165603,CF300,126&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45436,CF300,128&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45466,CF300,129&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45467,CF300,130&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45484,CF300,131&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45437,CF300,132&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45468,CF300,133&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45469,CF300,134&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45485,CF300,135&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46617,CF300,136&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46618,CF300,137&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46619,CF300,138&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46620,CF300,139&l=es

# %%
r  = requests.get("http://www.banxico.org.mx/SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCuadro&idCuadro=CF300&locale=es")

data = r.text

soup = BeautifulSoup(data,"lxml")

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://www.banxico.org.mx
# #
# #
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&idCuadro=CF300&accion=consultarCuadro&locale=en
# /SieInternet/
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarDirectorioCuadros&locale=es
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCarritoDeSeries&idCuadro=CF300&locale=es
# /SieInternet/consultarDirectorioInternetAction.do?sector=18&accion=consultarCarritoDeSeries&idCuadro=CF300&locale=es
# #
# /SieInternet/generaSerieGrafica.do?s=SF45422,CF300,2&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45438,CF300,3&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45439,CF300,4&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45470,CF300,5&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45423,CF300,6&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45440,CF300,7&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45441,CF300,8&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45471,CF300,9&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45424,CF300,10&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45442,CF300,11&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45443,CF300,12&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45472,CF300,13&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45425,CF300,14&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45444,CF300,15&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45445,CF300,16&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45473,CF300,17&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45426,CF300,19&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45446,CF300,20&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45447,CF300,21&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45474,CF300,22&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59767,CF300,24&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59773,CF300,25&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59774,CF300,26&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59770,CF300,27&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59768,CF300,28&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59775,CF300,29&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59776,CF300,30&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59771,CF300,31&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59769,CF300,32&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59777,CF300,33&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59778,CF300,34&l=es
# /SieInternet/generaSerieGrafica.do?s=SF59772,CF300,35&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45427,CF300,37&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45448,CF300,38&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45449,CF300,39&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45475,CF300,40&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45428,CF300,41&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45450,CF300,42&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45451,CF300,43&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45476,CF300,44&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45429,CF300,45&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45452,CF300,46&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45453,CF300,47&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45477,CF300,48&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45430,CF300,49&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45454,CF300,50&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45455,CF300,51&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45478,CF300,52&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45431,CF300,53&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45456,CF300,54&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45457,CF300,55&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45479,CF300,56&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60720,CF300,57&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60721,CF300,58&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60722,CF300,59&l=es
# /SieInternet/generaSerieGrafica.do?s=SF60723,CF300,60&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61784,CF300,62&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61785,CF300,63&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61786,CF300,64&l=es
# /SieInternet/generaSerieGrafica.do?s=SF61787,CF300,65&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45432,CF300,66&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45458,CF300,67&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45459,CF300,68&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45480,CF300,69&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50761,CF300,70&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50765,CF300,71&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50766,CF300,72&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50763,CF300,73&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50762,CF300,74&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50767,CF300,75&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50768,CF300,76&l=es
# /SieInternet/generaSerieGrafica.do?s=SF50764,CF300,77&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64846,CF300,79&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64847,CF300,80&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64848,CF300,81&l=es
# /SieInternet/generaSerieGrafica.do?s=SF64849,CF300,82&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108413,CF300,83&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108414,CF300,84&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108415,CF300,85&l=es
# /SieInternet/generaSerieGrafica.do?s=SF108416,CF300,86&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45433,CF300,87&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45460,CF300,88&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45461,CF300,89&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45481,CF300,90&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66800,CF300,92&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66801,CF300,93&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66802,CF300,94&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66803,CF300,95&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161926,CF300,96&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161928,CF300,97&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161930,CF300,98&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161932,CF300,99&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45435,CF300,100&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45464,CF300,101&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45465,CF300,102&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45483,CF300,103&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66804,CF300,105&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66805,CF300,106&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66806,CF300,107&l=es
# /SieInternet/generaSerieGrafica.do?s=SF66807,CF300,108&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161927,CF300,109&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161929,CF300,110&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161931,CF300,111&l=es
# /SieInternet/generaSerieGrafica.do?s=SF161933,CF300,112&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45434,CF300,113&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45462,CF300,114&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45463,CF300,115&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45482,CF300,116&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165596,CF300,118&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165598,CF300,119&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165600,CF300,120&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165602,CF300,121&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165597,CF300,123&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165599,CF300,124&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165601,CF300,125&l=es
# /SieInternet/generaSerieGrafica.do?s=SF165603,CF300,126&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45436,CF300,128&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45466,CF300,129&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45467,CF300,130&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45484,CF300,131&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45437,CF300,132&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45468,CF300,133&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45469,CF300,134&l=es
# /SieInternet/generaSerieGrafica.do?s=SF45485,CF300,135&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46617,CF300,136&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46618,CF300,137&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46619,CF300,138&l=es
# /SieInternet/generaSerieGrafica.do?s=SF46620,CF300,139&l=es

# %%
soup.find_all('input')
# Out:
# [<input id="cuadroBusqueda" placeholder="Buscar" style="height:25px;" type="text"/>,
#  <input name="idCuadro" type="hidden" value="CF300"/>,
#  <input name="sector" type="hidden" value="18"/>,
#  <input name="version" type="hidden" value="3"/>,
#  <input name="locale" type="hidden" value="es"/>,
#  <input alt="Consulta las series seleccionadas y las muestra en el navegador de Internet (HTML)." class="botonFormato" hl_hint="return '&lt;div class=\'hint\'&gt;Consulta las series seleccionadas &lt;br&gt;y las muestra en el navegador de Internet (HTML).&lt;/div&gt;'" id="formatoHTML" name="formatoHTML" onclick="document.consultarDirectorioActionForm.target='_blank'; return onClickConsultar() &amp;&amp; verificaLimiteSeries(this.form.series, 'Se permite consultar hasta 5,000 series. Por favor, seleccione un número menor de series.')" onmouseover="hl_show(event); document.getElementById('formatoHTML').alt='';" src="/SieInternet/img/ConsultarDirectorio/formato_HTML_Negro.png" style="border-radius:0px;" type="image"/>,
#  <input alt="Consulta las series seleccionadas en formato de hoja de cálculo (XLSX)." class="botonFormato" hl_hint="return '&lt;div class=\'hint\'&gt;Consulta las series seleccionadas &lt;br&gt;en formato de hoja de c&amp;aacute;lculo (XLSX).&lt;/div&gt;'" id="formatoXLS" name="formatoXLS" onclick="document.consultarDirectorioActionForm.target='_self'; return onClickConsultar() &amp;&amp; verificaLimiteSeries(this.form.series, 'Se permite consultar hasta 5,000 series. Por favor, seleccione un número menor de series.') " onmouseover="hl_show(event); document.getElementById('formatoXLS').alt='';" src="/SieInternet/img/ConsultarDirectorio/formato_XLSX_Negro.png" style="border-radius:0px;" type="image"/>,
#  <input alt="Consulta las series seleccionadas en formato de consulta web (IQY)." class="botonFormato" hl_hint="return '&lt;div class=\'hint\'&gt;Consulta las series seleccionadas &lt;br&gt;en formato de consulta web (IQY).&lt;/div&gt;'" id="formatoIQY" name="formatoIQY" onclick="document.consultarDirectorioActionForm.target='_self'; return onClickConsultar() &amp;&amp; verificaLimiteSeries(this.form.series, 'Se permite consultar hasta 5,000 series. Por favor, seleccione un número menor de series.') " onmouseover="hl_show(event); document.getElementById('formatoIQY').alt='';" src="/SieInternet/img/ConsultarDirectorio/formato_IQY_Negro.png" style="border-radius:0px;" type="image"/>,
#  <input alt="Consulta las series seleccionadas en formato separado por comas (CSV)." class="botonFormato" hl_hint="return '&lt;div class=\'hint\'&gt;Consulta las series seleccionadas &lt;br&gt;en formato separado por comas (CSV).&lt;/div&gt;'" id="formatoCSV" name="formatoCSV" onclick="document.consultarDirectorioActionForm.target='_self'; return onClickConsultar() &amp;&amp; verificaLimiteSeries(this.form.series, 'Se permite consultar hasta 5,000 series. Por favor, seleccione un número menor de series.');" onmouseover="hl_show(event); document.getElementById('formatoCSV').alt='';" src="/SieInternet/img/ConsultarDirectorio/formato_CSV_Negro.png" style="border-radius:0px;" type="image"/>,
#  <input alt="Consulta las series seleccionadas en formato XML (SDMX-ML)." class="botonFormato" hl_hint="return '&lt;div class=\'hint\'&gt;Consulta las series seleccionadas &lt;br&gt;en formato XML (SDMX-ML).&lt;/div&gt;'" id="formatoSDMX" name="formatoSDMX" onclick="document.consultarDirectorioActionForm.target='_self'; return onClickConsultar() &amp;&amp; verificaLimiteSDMX(this.form.series, 'Se permite consultar hasta 600 series. Por favor, seleccione un número menor de series.') " onmouseover="hl_show(event); document.getElementById('formatoSDMX').alt='';" src="/SieInternet/img/ConsultarDirectorio/formato_SDMX_Negro.png" style="border-radius:0px;" type="image"/>,
#  <input checked="checked" id="orientacionVertical" name="formatoHorizontal" style="padding: 0 1px 0 1px !important;" type="radio" value="false"/>,
#  <input id="orientacionHorizontal" name="formatoHorizontal" style="padding: 0 1px 0 3px !important;" type="radio" value="true"/>,
#  <input alt="Muestra información adicional sobre las series." checked="checked" id="metadatosWeb" name="metadatosWeb" style="padding: 0 0 0 1px !important;" type="checkbox" value="true"/>,
#  <input alt="Selecciona o desmarca todas las series." checked="checked" hl_hint="return '&lt;div class=\'hint\'&gt;Selecciona o desmarca todas las series.&lt;/div&gt;'" id="seleccionaTodasSeries" onclick="$('input[name=series]').prop('checked', $('#seleccionaTodasSeries').prop('checked'));" onmouseover="hl_show(event); document.getElementById('seleccionaTodasSeries').alt='';" style="margin-left:5px" type="checkbox"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45422"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45438"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45439"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45470"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45423"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45440"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45441"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45471"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45424"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45442"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45443"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45472"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45425"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45444"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45445"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45473"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45426"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45446"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45447"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45474"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59767"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59773"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59774"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59770"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59768"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59775"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59776"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59771"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59769"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59777"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59778"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF59772"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45427"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45448"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45449"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45475"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45428"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45450"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45451"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45476"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45429"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45452"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45453"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45477"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45430"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45454"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45455"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45478"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45431"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45456"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45457"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45479"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF60720"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF60721"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF60722"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF60723"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF61784"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF61785"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF61786"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF61787"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45432"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45458"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45459"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45480"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50761"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50765"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50766"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50763"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50762"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50767"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50768"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF50764"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF64846"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF64847"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF64848"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF64849"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF108413"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF108414"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF108415"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF108416"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45433"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45460"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45461"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45481"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66800"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66801"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66802"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66803"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161926"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161928"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161930"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161932"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45435"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45464"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45465"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45483"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66804"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66805"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66806"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF66807"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161927"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161929"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161931"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF161933"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45434"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45462"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45463"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45482"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165596"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165598"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165600"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165602"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165597"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165599"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165601"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF165603"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45436"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45466"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45467"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45484"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45437"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45468"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45469"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF45485"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF46617"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF46618"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF46619"/>,
#  <input checked="checked" name="series" type="checkbox" value="SF46620"/>]

# %%
for html_input in soup.find_all('input'):
    if html_input['type']=='checkbox':
        print(html_input)
# Out:
# <input alt="Muestra información adicional sobre las series." checked="checked" id="metadatosWeb" name="metadatosWeb" style="padding: 0 0 0 1px !important;" type="checkbox" value="true"/>
# <input alt="Selecciona o desmarca todas las series." checked="checked" hl_hint="return '&lt;div class=\'hint\'&gt;Selecciona o desmarca todas las series.&lt;/div&gt;'" id="seleccionaTodasSeries" onclick="$('input[name=series]').prop('checked', $('#seleccionaTodasSeries').prop('checked'));" onmouseover="hl_show(event); document.getElementById('seleccionaTodasSeries').alt='';" style="margin-left:5px" type="checkbox"/>
# <input checked="checked" name="series" type="checkbox" value="SF45422"/>
# <input checked="checked" name="series" type="checkbox" value="SF45438"/>
# <input checked="checked" name="series" type="checkbox" value="SF45439"/>
# <input checked="checked" name="series" type="checkbox" value="SF45470"/>
# <input checked="checked" name="series" type="checkbox" value="SF45423"/>
# <input checked="checked" name="series" type="checkbox" value="SF45440"/>
# <input checked="checked" name="series" type="checkbox" value="SF45441"/>
# <input checked="checked" name="series" type="checkbox" value="SF45471"/>
# <input checked="checked" name="series" type="checkbox" value="SF45424"/>
# <input checked="checked" name="series" type="checkbox" value="SF45442"/>
# <input checked="checked" name="series" type="checkbox" value="SF45443"/>
# <input checked="checked" name="series" type="checkbox" value="SF45472"/>
# <input checked="checked" name="series" type="checkbox" value="SF45425"/>
# <input checked="checked" name="series" type="checkbox" value="SF45444"/>
# <input checked="checked" name="series" type="checkbox" value="SF45445"/>
# <input checked="checked" name="series" type="checkbox" value="SF45473"/>
# <input checked="checked" name="series" type="checkbox" value="SF45426"/>
# <input checked="checked" name="series" type="checkbox" value="SF45446"/>
# <input checked="checked" name="series" type="checkbox" value="SF45447"/>
# <input checked="checked" name="series" type="checkbox" value="SF45474"/>
# <input checked="checked" name="series" type="checkbox" value="SF59767"/>
# <input checked="checked" name="series" type="checkbox" value="SF59773"/>
# <input checked="checked" name="series" type="checkbox" value="SF59774"/>
# <input checked="checked" name="series" type="checkbox" value="SF59770"/>
# <input checked="checked" name="series" type="checkbox" value="SF59768"/>
# <input checked="checked" name="series" type="checkbox" value="SF59775"/>
# <input checked="checked" name="series" type="checkbox" value="SF59776"/>
# <input checked="checked" name="series" type="checkbox" value="SF59771"/>
# <input checked="checked" name="series" type="checkbox" value="SF59769"/>
# <input checked="checked" name="series" type="checkbox" value="SF59777"/>
# <input checked="checked" name="series" type="checkbox" value="SF59778"/>
# <input checked="checked" name="series" type="checkbox" value="SF59772"/>
# <input checked="checked" name="series" type="checkbox" value="SF45427"/>
# <input checked="checked" name="series" type="checkbox" value="SF45448"/>
# <input checked="checked" name="series" type="checkbox" value="SF45449"/>
# <input checked="checked" name="series" type="checkbox" value="SF45475"/>
# <input checked="checked" name="series" type="checkbox" value="SF45428"/>
# <input checked="checked" name="series" type="checkbox" value="SF45450"/>
# <input checked="checked" name="series" type="checkbox" value="SF45451"/>
# <input checked="checked" name="series" type="checkbox" value="SF45476"/>
# <input checked="checked" name="series" type="checkbox" value="SF45429"/>
# <input checked="checked" name="series" type="checkbox" value="SF45452"/>
# <input checked="checked" name="series" type="checkbox" value="SF45453"/>
# <input checked="checked" name="series" type="checkbox" value="SF45477"/>
# <input checked="checked" name="series" type="checkbox" value="SF45430"/>
# <input checked="checked" name="series" type="checkbox" value="SF45454"/>
# <input checked="checked" name="series" type="checkbox" value="SF45455"/>
# <input checked="checked" name="series" type="checkbox" value="SF45478"/>
# <input checked="checked" name="series" type="checkbox" value="SF45431"/>
# <input checked="checked" name="series" type="checkbox" value="SF45456"/>
# <input checked="checked" name="series" type="checkbox" value="SF45457"/>
# <input checked="checked" name="series" type="checkbox" value="SF45479"/>
# <input checked="checked" name="series" type="checkbox" value="SF60720"/>
# <input checked="checked" name="series" type="checkbox" value="SF60721"/>
# <input checked="checked" name="series" type="checkbox" value="SF60722"/>
# <input checked="checked" name="series" type="checkbox" value="SF60723"/>
# <input checked="checked" name="series" type="checkbox" value="SF61784"/>
# <input checked="checked" name="series" type="checkbox" value="SF61785"/>
# <input checked="checked" name="series" type="checkbox" value="SF61786"/>
# <input checked="checked" name="series" type="checkbox" value="SF61787"/>
# <input checked="checked" name="series" type="checkbox" value="SF45432"/>
# <input checked="checked" name="series" type="checkbox" value="SF45458"/>
# <input checked="checked" name="series" type="checkbox" value="SF45459"/>
# <input checked="checked" name="series" type="checkbox" value="SF45480"/>
# <input checked="checked" name="series" type="checkbox" value="SF50761"/>
# <input checked="checked" name="series" type="checkbox" value="SF50765"/>
# <input checked="checked" name="series" type="checkbox" value="SF50766"/>
# <input checked="checked" name="series" type="checkbox" value="SF50763"/>
# <input checked="checked" name="series" type="checkbox" value="SF50762"/>
# <input checked="checked" name="series" type="checkbox" value="SF50767"/>
# <input checked="checked" name="series" type="checkbox" value="SF50768"/>
# <input checked="checked" name="series" type="checkbox" value="SF50764"/>
# <input checked="checked" name="series" type="checkbox" value="SF64846"/>
# <input checked="checked" name="series" type="checkbox" value="SF64847"/>
# <input checked="checked" name="series" type="checkbox" value="SF64848"/>
# <input checked="checked" name="series" type="checkbox" value="SF64849"/>
# <input checked="checked" name="series" type="checkbox" value="SF108413"/>
# <input checked="checked" name="series" type="checkbox" value="SF108414"/>
# <input checked="checked" name="series" type="checkbox" value="SF108415"/>
# <input checked="checked" name="series" type="checkbox" value="SF108416"/>
# <input checked="checked" name="series" type="checkbox" value="SF45433"/>
# <input checked="checked" name="series" type="checkbox" value="SF45460"/>
# <input checked="checked" name="series" type="checkbox" value="SF45461"/>
# <input checked="checked" name="series" type="checkbox" value="SF45481"/>
# <input checked="checked" name="series" type="checkbox" value="SF66800"/>
# <input checked="checked" name="series" type="checkbox" value="SF66801"/>
# <input checked="checked" name="series" type="checkbox" value="SF66802"/>
# <input checked="checked" name="series" type="checkbox" value="SF66803"/>
# <input checked="checked" name="series" type="checkbox" value="SF161926"/>
# <input checked="checked" name="series" type="checkbox" value="SF161928"/>
# <input checked="checked" name="series" type="checkbox" value="SF161930"/>
# <input checked="checked" name="series" type="checkbox" value="SF161932"/>
# <input checked="checked" name="series" type="checkbox" value="SF45435"/>
# <input checked="checked" name="series" type="checkbox" value="SF45464"/>
# <input checked="checked" name="series" type="checkbox" value="SF45465"/>
# <input checked="checked" name="series" type="checkbox" value="SF45483"/>
# <input checked="checked" name="series" type="checkbox" value="SF66804"/>
# <input checked="checked" name="series" type="checkbox" value="SF66805"/>
# <input checked="checked" name="series" type="checkbox" value="SF66806"/>
# <input checked="checked" name="series" type="checkbox" value="SF66807"/>
# <input checked="checked" name="series" type="checkbox" value="SF161927"/>
# <input checked="checked" name="series" type="checkbox" value="SF161929"/>
# <input checked="checked" name="series" type="checkbox" value="SF161931"/>
# <input checked="checked" name="series" type="checkbox" value="SF161933"/>
# <input checked="checked" name="series" type="checkbox" value="SF45434"/>
# <input checked="checked" name="series" type="checkbox" value="SF45462"/>
# <input checked="checked" name="series" type="checkbox" value="SF45463"/>
# <input checked="checked" name="series" type="checkbox" value="SF45482"/>
# <input checked="checked" name="series" type="checkbox" value="SF165596"/>
# <input checked="checked" name="series" type="checkbox" value="SF165598"/>
# <input checked="checked" name="series" type="checkbox" value="SF165600"/>
# <input checked="checked" name="series" type="checkbox" value="SF165602"/>
# <input checked="checked" name="series" type="checkbox" value="SF165597"/>
# <input checked="checked" name="series" type="checkbox" value="SF165599"/>
# <input checked="checked" name="series" type="checkbox" value="SF165601"/>
# <input checked="checked" name="series" type="checkbox" value="SF165603"/>
# <input checked="checked" name="series" type="checkbox" value="SF45436"/>
# <input checked="checked" name="series" type="checkbox" value="SF45466"/>
# <input checked="checked" name="series" type="checkbox" value="SF45467"/>
# <input checked="checked" name="series" type="checkbox" value="SF45484"/>
# <input checked="checked" name="series" type="checkbox" value="SF45437"/>
# <input checked="checked" name="series" type="checkbox" value="SF45468"/>
# <input checked="checked" name="series" type="checkbox" value="SF45469"/>
# <input checked="checked" name="series" type="checkbox" value="SF45485"/>
# <input checked="checked" name="series" type="checkbox" value="SF46617"/>
# <input checked="checked" name="series" type="checkbox" value="SF46618"/>
# <input checked="checked" name="series" type="checkbox" value="SF46619"/>
# <input checked="checked" name="series" type="checkbox" value="SF46620"/>

# %%
for html_input in soup.find_all('input'):
    if html_input['type']=='checkbox':
        try:
            if html_input['value'][:2]=='SF':
                print(html_input['value'])
        except:
            print(html_input.attrs)
# Out:
# {'alt': 'Selecciona o desmarca todas las series.', 'id': 'seleccionaTodasSeries', 'type': 'checkbox', 'checked': 'checked', 'onmouseover': "hl_show(event); document.getElementById('seleccionaTodasSeries').alt='';", 'style': 'margin-left:5px', 'hl_hint': "return '<div class=\\'hint\\'>Selecciona o desmarca todas las series.</div>'", 'onclick': "$('input[name=series]').prop('checked', $('#seleccionaTodasSeries').prop('checked'));"}
# SF45422
# SF45438
# SF45439
# SF45470
# SF45423
# SF45440
# SF45441
# SF45471
# SF45424
# SF45442
# SF45443
# SF45472
# SF45425
# SF45444
# SF45445
# SF45473
# SF45426
# SF45446
# SF45447
# SF45474
# SF59767
# SF59773
# SF59774
# SF59770
# SF59768
# SF59775
# SF59776
# SF59771
# SF59769
# SF59777
# SF59778
# SF59772
# SF45427
# SF45448
# SF45449
# SF45475
# SF45428
# SF45450
# SF45451
# SF45476
# SF45429
# SF45452
# SF45453
# SF45477
# SF45430
# SF45454
# SF45455
# SF45478
# SF45431
# SF45456
# SF45457
# SF45479
# SF60720
# SF60721
# SF60722
# SF60723
# SF61784
# SF61785
# SF61786
# SF61787
# SF45432
# SF45458
# SF45459
# SF45480
# SF50761
# SF50765
# SF50766
# SF50763
# SF50762
# SF50767
# SF50768
# SF50764
# SF64846
# SF64847
# SF64848
# SF64849
# SF108413
# SF108414
# SF108415
# SF108416
# SF45433
# SF45460
# SF45461
# SF45481
# SF66800
# SF66801
# SF66802
# SF66803
# SF161926
# SF161928
# SF161930
# SF161932
# SF45435
# SF45464
# SF45465
# SF45483
# SF66804
# SF66805
# SF66806
# SF66807
# SF161927
# SF161929
# SF161931
# SF161933
# SF45434
# SF45462
# SF45463
# SF45482
# SF165596
# SF165598
# SF165600
# SF165602
# SF165597
# SF165599
# SF165601
# SF165603
# SF45436
# SF45466
# SF45467
# SF45484
# SF45437
# SF45468
# SF45469
# SF45485
# SF46617
# SF46618
# SF46619
# SF46620

# %%
for html_input in soup.find_all('input',{'value':True}):
    if html_input['type']=='checkbox' and html_input['value'][:2]=='SF':
        print(html_input['value'])
# Out:
# SF45422
# SF45438
# SF45439
# SF45470
# SF45423
# SF45440
# SF45441
# SF45471
# SF45424
# SF45442
# SF45443
# SF45472
# SF45425
# SF45444
# SF45445
# SF45473
# SF45426
# SF45446
# SF45447
# SF45474
# SF59767
# SF59773
# SF59774
# SF59770
# SF59768
# SF59775
# SF59776
# SF59771
# SF59769
# SF59777
# SF59778
# SF59772
# SF45427
# SF45448
# SF45449
# SF45475
# SF45428
# SF45450
# SF45451
# SF45476
# SF45429
# SF45452
# SF45453
# SF45477
# SF45430
# SF45454
# SF45455
# SF45478
# SF45431
# SF45456
# SF45457
# SF45479
# SF60720
# SF60721
# SF60722
# SF60723
# SF61784
# SF61785
# SF61786
# SF61787
# SF45432
# SF45458
# SF45459
# SF45480
# SF50761
# SF50765
# SF50766
# SF50763
# SF50762
# SF50767
# SF50768
# SF50764
# SF64846
# SF64847
# SF64848
# SF64849
# SF108413
# SF108414
# SF108415
# SF108416
# SF45433
# SF45460
# SF45461
# SF45481
# SF66800
# SF66801
# SF66802
# SF66803
# SF161926
# SF161928
# SF161930
# SF161932
# SF45435
# SF45464
# SF45465
# SF45483
# SF66804
# SF66805
# SF66806
# SF66807
# SF161927
# SF161929
# SF161931
# SF161933
# SF45434
# SF45462
# SF45463
# SF45482
# SF165596
# SF165598
# SF165600
# SF165602
# SF165597
# SF165599
# SF165601
# SF165603
# SF45436
# SF45466
# SF45467
# SF45484
# SF45437
# SF45468
# SF45469
# SF45485
# SF46617
# SF46618
# SF46619
# SF46620

# %%
checkboxes = []
for html_input in soup.find_all('input',{'value':True}):
    if html_input['type']=='checkbox' and html_input['value'][:2]=='SF':
        checkboxes.append(html_input['value'])
print(checkboxes)
# Out:
# ['SF45422', 'SF45438', 'SF45439', 'SF45470', 'SF45423', 'SF45440', 'SF45441', 'SF45471', 'SF45424', 'SF45442', 'SF45443', 'SF45472', 'SF45425', 'SF45444', 'SF45445', 'SF45473', 'SF45426', 'SF45446', 'SF45447', 'SF45474', 'SF59767', 'SF59773', 'SF59774', 'SF59770', 'SF59768', 'SF59775', 'SF59776', 'SF59771', 'SF59769', 'SF59777', 'SF59778', 'SF59772', 'SF45427', 'SF45448', 'SF45449', 'SF45475', 'SF45428', 'SF45450', 'SF45451', 'SF45476', 'SF45429', 'SF45452', 'SF45453', 'SF45477', 'SF45430', 'SF45454', 'SF45455', 'SF45478', 'SF45431', 'SF45456', 'SF45457', 'SF45479', 'SF60720', 'SF60721', 'SF60722', 'SF60723', 'SF61784', 'SF61785', 'SF61786', 'SF61787', 'SF45432', 'SF45458', 'SF45459', 'SF45480', 'SF50761', 'SF50765', 'SF50766', 'SF50763', 'SF50762', 'SF50767', 'SF50768', 'SF50764', 'SF64846', 'SF64847', 'SF64848', 'SF64849', 'SF108413', 'SF108414', 'SF108415', 'SF108416', 'SF45433', 'SF45460', 'SF45461', 'SF45481', 'SF66800', 'SF66801', 'SF66802', 'SF66803', 'SF161926', 'SF161928', 'SF161930', 'SF161932', 'SF45435', 'SF45464', 'SF45465', 'SF45483', 'SF66804', 'SF66805', 'SF66806', 'SF66807', 'SF161927', 'SF161929', 'SF161931', 'SF161933', 'SF45434', 'SF45462', 'SF45463', 'SF45482', 'SF165596', 'SF165598', 'SF165600', 'SF165602', 'SF165597', 'SF165599', 'SF165601', 'SF165603', 'SF45436', 'SF45466', 'SF45467', 'SF45484', 'SF45437', 'SF45468', 'SF45469', 'SF45485', 'SF46617', 'SF46618', 'SF46619', 'SF46620']

# %%
#No estaba guardando las series que se habian generado, por eso mi error, ya se corrigio el codigo 400 y 500 de salida
series =[ ("series",html_input['value'])  for html_input in soup.find_all('input',{'value':True}) if html_input['type']=='checkbox' and html_input['value'][:2]=='SF']

# %% [markdown]
# # Ejercicio
#
# 1. Completa el ejercicio en Python de la siguiente manera.
#     1. Descarga un archivo CSV con todas las Series que existen en la página web para los años 2015-2017.
#         2. Ejemplo de archivo esperado.
#         ```
#         "Fecha","SF45422","SF45438","SF45439","SF45470","SF45423"....
#         16/05/2015,27.000000,9.956650,9.956650,5.805165,90.000000
#         19/05/2015,24.000000,9.961733,9.961733,5.762100,87.000000
#         20/05/2015,23.000000,9.965181,9.965181,5.468973,86.000000
#         21/05/2015,22.000000,9.968039,9.968039,5.246751,85.000000
#         22/05/2015,28.000000,9.960956,9.960956,5.039620,91.000000
#         23/05/2015,27.000000,9.962875,9.962875,4.968445,90.000000
#         ```
#     La salida esperada es un archivo .py.
#
# 2. Repite el ejercicio 1.1 anterior desde shell.
#     1. Busca los valores del checkbox.
#     2. Formatea el url para pedir los archivos csv
#     3. Haz la petición con curl y genera el archivo CSV de salida.
#     4. Modifica la codifiación del archivo CSV a utf-8.
#
#     La salida esperada es un archivo Bash.

# %%
class descarga(object):
    def __init__(self):
        self.search_request = [
            ('idCuadro', 'CF300'),
            ('sector', '18'),
            ('version', '3'),
            ('locale', 'es'),
            ('formatoCSV.x', '41'),
            ('formatoCSV.y', '20'),
            ('anoInicial', '2015'),
            ('anoFinal', '2017'),
            ('tipoInformacion', ''),
            ('formatoHorizontal', 'false'),
            ('metadatosWeb', 'true')
        ]
        self.search_request = self.search_request + series
        self.headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.90 Safari/537.36'}
       
    def scrape(self):
        params = (('accion', 'consultarSeries'),)
        url = 'http://www.banxico.org.mx/SieInternet/consultarDirectorioInternetAction.do'
        global r2
        r2 = requests.post(url, data=self.search_request,headers=self.headers,params=params) # headers=self.headers
        print("El codigo de respuesta es: %s" % r2)

# %%
s = descarga()
s.scrape()
# Out:
# El codigo de respuesta es: <Response [200]>

# %%
r2 = BeautifulSoup(r2.text.encode("utf-8"), 'html.parser')

# %%
r2 = r2.text.split("\r\n")
r2 = r2[17:len(r2)]

# %%
for i in range(len(r2)):
    r2[i]=r2[i].split(",")

# %%
import pandas as pd
r2 = pd.DataFrame(r2)

# %%
r2.to_csv("output.csv", sep=',', encoding='utf-8')
